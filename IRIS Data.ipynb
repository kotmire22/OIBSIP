# %% [markdown]
# # Assigned Task
# Iris flower has three species; setosa, versicolor, and virginica, which differs according to their
# measurements. Now assume that you have the measurements of the iris flowers according to
# their species, and here your task is to train a machine learning model that can learn from the
# measurements of the iris species and classify them.

# %%
import pandas as pd
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
import matplotlib
from sklearn import metrics

# %%
import warnings

# %%
warnings.simplefilter("ignore")

# %%
flower=pd.read_csv(r"C:\Users\tejas\OneDrive\Desktop\Machine Leaening\archive (9)\Iris.csv")
flower
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
flower.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# ###  This IRIS flower data set is clean then  we no need to clean it and all the feature of flower are in numerical data so no need to convert it.

# %%
flower["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
flower=flower.drop('Id',axis=1)

# %%
flower.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
flower["Species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ### The flower has only three type of species
# ### 1.Setosa
# ### 2.Versicolor
# ### 3.Virginica

# %%
flower.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
flower.columns
# Out:
# Index(['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# ####  DataSet Visualization

# %%
co=flower[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
       'Species']].corr()
sns.heatmap(co,cmap="PiYG",annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(data=flower, hue='Species', size=3)

# %%
g = sns.pairplot(flower, diag_kind="kde")
g.map_lower(sns.kdeplot, levels=4, color=".2")

# %% [markdown]
# ### Machine Learning Algorithm & Model Building

# %% [markdown]
# ###### We have to Classify the flower type using flower feature so this is a Supervised Learning Classification Problem

# %%
from sklearn.model_selection import train_test_split

# %%
x=flower[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]
y=flower["Species"]

# %%
#Y=y.array.reshape(-2,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=2)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (105, 4)
# (45, 4)
# (105,)
# (45,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg=LogisticRegression()

# %%
logreg.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=logreg.predict(X_test)

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.9777777777777777

# %%
from sklearn.tree import DecisionTreeClassifier
dtclf = DecisionTreeClassifier(criterion='entropy')

# %%
dtclf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
Y_pred=dtclf.predict(X_test)

# %%
metrics.accuracy_score(y_test,Y_pred)
# Out:
# 0.9555555555555556

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier(criterion='entropy')
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
import graphviz 
from sklearn.tree import export_graphviz

# %%
dot_data = export_graphviz(clf, 
                         out_file=None, 
                         feature_names=flower.drop('Species',1).columns,  
                         class_names=flower["Species"].unique(),  
                          filled=True, 
                          rounded=True,
                          special_characters= False)  
graph = graphviz.Source(dot_data)

# %%
graph

# %%
dtclf.predict(pd.DataFrame([[0.2,1.5,2.2,1.5]],
                         columns=[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]))
# Out:
# array(['Iris-setosa'], dtype=object)

# %% [markdown]
# ### We have Predict The the flower type using flower Feature Like Sepal length,Sepal Width ,Petal length, Petal Width

# %%
logreg.predict(pd.DataFrame([[0.2,1.5,2.2,1.5]],
                         columns=[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]))
# Out:
# array(['Iris-setosa'], dtype=object)

# %%
dtclf.predict(pd.DataFrame([[6.7,3.0,5.2,2.5]],
                         columns=[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]))
# Out:
# array(['Iris-virginica'], dtype=object)

# %%
dtclf.predict(pd.DataFrame([[5.2,4.5,3.5,0.7]],
                         columns=[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']]))
# Out:
# array(['Iris-versicolor'], dtype=object)
